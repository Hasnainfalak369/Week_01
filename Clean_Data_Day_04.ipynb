# %% [markdown]
# # Learn_Python_With_Baba_Ammar Day_4
# -----

# %% [markdown]
# ### DATA Set Reference
# #### Clean Data_Class_Survey
# ### Dots In JupyterNotebook Library
# ### Seaborn Gallery
# ----

# %%
#In first step install all useful libraries and then run
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#In secondstep Upload Csv file and then run
clndata=pd.read_csv("E:\\Python Chilla\\Chilla_data2.csv")

clndata.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
#Defing color Palette
p=sns.color_palette("pastel")

# %%
#Plot line plot

# %%
sns.relplot(data=clndata, x="Age", y="Your Weight in kg? (float)",
            hue="Where do you live?",  size_order=["T1","T2"],height=5, aspect=.75, facet_kws=dict(sharex=False),)
plt.show()

# %%
#violinplot

# %%
sns.violinplot(data=clndata,x="Gender",y="How many hours you code a day? (int) e.g: 5,4,3",
               hue="Are you Vaccinated?",split=True,Inner="quart",
               linewidth=1,palette={"Yes":"b","No":".85"})
sns.despine(left=True)

# %%
#Scatter plot

# %%
sns.set_theme(style="whitegrid")
f,ax=plt.subplots(figsize=(6.5,6.5))
sns.despine(f, left=True,bottom=True)
clarity_ranking=["I1","SI2","VS2","VS1","WS2","WS1","IF"]

sns.scatterplot(data=clndata,x="Gender",y="How many hours you code a day? (int) e.g: 5,4,3",ax=ax)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='How many hours you code a day? (int) e.g: 5,4,3'>

# %%
sns.boxplot(data=clndata, x="Age", y="Your Weight in kg? (float)",
            hue="Where do you live?")
plt.show()

# %%
sns.boxenplot(data=clndata, x="Age", y="Your Weight in kg? (float)",
            hue="Where do you live?",color="red")
plt.show()

# %%
#Pair plot
sns.set_theme(style="ticks")
sns.pairplot(clndata, hue="Age")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
sns.despine(left=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid", palette="muted")

# Load the penguins dataset
df = sns.load_dataset("penguins")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="body_mass_g", y="sex", hue="species")
ax.set(ylabel="")
# Out:
# [Text(0, 0.5, '')]
