# %% [markdown]
# # Learn_pythn ka_Chilla_With_Baba_Ammar Day_4
# ----

# %% [markdown]
# ## Line_Bar_Plots
# -----

# %% [markdown]
# ### Tittle                "Research Scholar"
# ### Name                  " Muhammad Hasnain"
# ### Emial                 "mhasnain@ele.qau.edu.pk"
# ### Whatsaap no           " +923006054928"
# --------

# %%
from numpy import median
import seaborn as sns
import matplotlib.pyplot as plt

# %%
phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.barplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
sns.boxplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
sns.catplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
sns.relplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
sns.rugplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
plt.title("Garden m phool")
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.xlim(3)
plt.ylim(1)
plt.show()

# %%
phool = sns.load_dataset("iris")
plt.figure(figsize=(5,6))
sns.barplot(x="species", y= "sepal_width", data= phool)
plt.title("Phool")
plt.show()

# %%
phool = sns.load_dataset("iris")
plt.figure(figsize=(5,6))
sns.barplot(x="species", y= "petal_length", data= phool)
plt.title("Phool")
plt.show()

# %%
kashti= sns.load_dataset("titanic")
kashti
plt.figure(figsize=(5,6))
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti)
plt.title("kashti")
plt.show()

# %%
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti, order=["male","female"])
plt.title("kashti")
plt.show()

# %%
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti, order=["male","female"], color="Green")
plt.title("kashti")
plt.show()

# %%
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti, order=["male","female"], color="Green", ci=None)
plt.title("kashti")
plt.show()

# %%
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti, order=["male","female"], color="Green", ci=None,palette= "colorblind")
plt.title("kashti")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
kashti= sns.load_dataset("titanic")
sns.barplot(x="sex", y= "alone", hue=("who"), data= kashti, order=["male","female"], color="Green")
plt.title("kashti")
plt.show()

# %%
kashti= sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.(x="age", y= "pclass", hue="sex", data = kashti)
plt.title("kashti")
plt.show()
