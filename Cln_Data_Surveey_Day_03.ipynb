# %% [markdown]
# # Learn_Python_with_Baba_Ammar Day_3
# ----

# %% [markdown]
# ### Tittle "Research Scholar"
# ### Name   "Muhammad Hasnain"
# ### Email "mhasnain@ele.qau.edu.pk"
# ### Whatsapp no "+923006054928"
# ----

# %% [markdown]
# # Clean Data_survey
# ___

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AssigmtClndata2 =pd.read_csv("E:\\python Chilla\\Chilla_data2.csv") 
AssigmtClndata2
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
sns.barplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Where do you live?" , data= AssigmtClndata2)
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.lineplot( x="What are you?",y="Research/Working experience (Float/Int) years" , data= AssigmtClndata2, color="Green")
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.barplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Green")
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.lineplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Green")
sns.set_style("dark")
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.lineplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Green")
sns.set_style("dark")
plt.xlim(1)
plt.ylim(2)
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.barplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Green")
sns.set_style("dark")
plt.xlim(1)
plt.ylim(4)
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.boxenplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="black")
sns.set_style("dark")
plt.xlim(1)
plt.ylim(4)
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.boxplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Blue")
sns.set_style("dark")
plt.xlim(1)
plt.ylim(4)
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.boxplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Blue")
plt.figure(figsize=(8,9))
sns.set_style("dark")
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')

# %%
sns.lineplot( x="How many hours you code a day? (int) e.g: 5,4,3",y="Research/Working experience (Float/Int) years" , 
            data= AssigmtClndata2, color="Blue")
plt.figure(figsize=(8,9))
sns.set_style("dark")
plt.title("Day4 Surrvey")
# Out:
# Text(0.5, 1.0, 'Day4 Surrvey')
