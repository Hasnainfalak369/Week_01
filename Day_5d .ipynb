# %% [markdown]
# # Learn_Python_Ka Chilla_With Baba_Ammar_Day_5_d
# ---

# %% [markdown]
# ## line plot with multifacets
# ----

# %% [markdown]
# ### Tittle "Research Scholar"
# ### Name   "Muhammad Hasnain"
# ### Email  "mhasnain@ele.qau.edu.pk"
# ### Whatsapp "+923006054928"
# ----

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
nuqta= sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(data=nuqta, x="coherence",y="firing_rate",hue="time",
           size="choice",col="align",kind="line")

# %%
sns.relplot(data=nuqta, x="coherence",y="firing_rate",hue="time",
           size="choice",col="align",kind="line",
           height=5,aspect=.75, facet_kws=dict(sharex=False),)

# %%
tip=sns.load_dataset("tips")
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day",y='total_bill',hue="smoker",
            palette=["m","g"],data=tip)
sns.despine(offset=10, trim=True)
