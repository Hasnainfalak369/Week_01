# %% [markdown]
# # Learn_Python_Ka_Chilla_with_baba_Ammar_Day_8
# ----

# %% [markdown]
# ### Tittle "Research Scholar"
# ### Name "Muhammad Hasnain"
# ### Email "mhasnain@ele.qau.edu.pk"
# ### Whats'p no "+92300_6054928"
# ---

# %% [markdown]
# ### Data Reference
# #### All data collected from youtube chanal Viedo Seriers Week 01
#
# ### https://www.youtube.com/channel/UCmNXJXWONLNF6bdftGY0Otw
# ----

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
Codanics=pd.read_csv("E:\\DATASET_CSV\\Videos_data.csv")
Codanics
# Out:
#          Date  Video Time length in (M) Total Comments  Like    Dislike  \
# 0   27-Dec-21                        25            568     876        0
# 1   28-Dec-21                        23            212     373        0
# 2   29-Dec-21                       115          1,009     294        0
# 3    1-Jan-22                        99            208     509        0
# 4    1-Jan-22                        32            161     203        0
# 5    2-Jan-22                        21             57     113        0
# 6    2-Jan-22                        42            103     154        0
# 7    3-Jan-22                       126            125     120        0
# 8    3-Jan-22                       116             60     179        0
# 9    4-Jan-22                        30            116     123        0
# 10   4-Jan-22                        42             17     121        0
# 11   5-Jan-22                        50            107      89        0
# ...

# %%
sns.barplot(x="Video Time length in (M)",y="Total Views",data=Codanics)
# Out:
# <AxesSubplot:xlabel='Video Time length in (M)', ylabel='Total Views'>

# %%
sns.boxplot(x="Video Time length in (M)",y="Total Views",data=Codanics)
# Out:
# <AxesSubplot:xlabel='Video Time length in (M)', ylabel='Total Views'>

# %%
sns.lineplot(x="Video Time length in (M)",y="Total Views",data=Codanics)
# Out:
# <AxesSubplot:xlabel='Video Time length in (M)', ylabel='Total Views'>

# %%
sns.barplot(x="Video Time length in (M)",y="Total Views",data=Codanics)
plt.title("Python_Chilla Week1 Videos Data")
# Out:
# Text(0.5, 1.0, 'Python_Chilla Week1 Videos Data')

# %%
sns.scatterplot(x="Video Time length in (M)",y="Total Views",data=Codanics,color='red',)
plt.title("Python_Chilla Week1 Videos Data",weight="bold")
# Out:
# Text(0.5, 1.0, 'Python_Chilla Week1 Videos Data')

# %%
sns.boxenplot(x="Video Time length in (M)",y="Total Views",hue="Dislike" ,data=Codanics,color='red',)
plt.title("Python_Chilla Week1 Videos Data",weight="bold")
# Out:
# Text(0.5, 1.0, 'Python_Chilla Week1 Videos Data')

# %%
sns.set_theme(style="ticks")
sns.pairplot(Codanics, hue="Dislike")

# %%
Codanics.head()
# Out:
#         Date  Video Time length in (M) Total Comments  Like    Dislike  Share  \
# 0  27-Dec-21                        25            568     876        0      0
# 1  28-Dec-21                        23            212     373        0      0
# 2  29-Dec-21                       115          1,009     294        0      0
# 3   1-Jan-22                        99            208     509        0      0
# 4   1-Jan-22                        32            161     203        0      0
#
#     Video's uploded in single day Total Views
# 0                               2      14,200
# 1                               1       9,983
# 2                               1       8,458
# 3                               2       5,699
# 4                               2       3,946

# %%
sns.violinplot(data=Codanics, x="Total Comments", y="Video Time length in (M)",split=True, inner="quart", linewidth=1,color="Green")
sns.despine(left=True)

# %%
ax = sns.swarmplot(data=Codanics, x="Total Comments", y="Total Views")
ax.set(ylabel="*")
# Out:
# [Text(0, 0.5, '*')]

# %%
import plotly.express as px

sns.catplot(x="Total Comments", y="Total Views", data=Codanics)
